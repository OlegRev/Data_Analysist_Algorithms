# %% [markdown]
# ## Генерируем данные

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
from sklearn import datasets
from matplotlib.colors import ListedColormap

# сгеренируем данные с помощью sklearn.datasets
classes = datasets.make_classification(n_samples=100, n_features=2, n_informative=2,
                                       n_redundant=0, n_classes=2, random_state=1)
# datasets.make_blobs(centers = 2, cluster_std = 1.5, random_state=12)

# и изобразим их на графике
colors = ListedColormap(['red', 'blue'])

plt.figure(figsize=(8, 8))
plt.scatter([x[0] for x in classes[0]], [x[1] for x in classes[0]], c=classes[1], cmap=colors)

# %% [markdown]
# ## Реализация логистической регрессии

# %%
# перемешивание датасета
np.random.seed(12)
shuffle_index = np.random.permutation(classes[0].shape[0])
X_shuffled, y_shuffled = classes[0][shuffle_index], classes[1][shuffle_index]

# разбивка на обучающую и тестовую выборки
train_proportion = 0.7
train_test_cut = int(len(classes[0]) * train_proportion)

X_train, X_test, y_train, y_test = \
    X_shuffled[:train_test_cut], \
    X_shuffled[train_test_cut:], \
    y_shuffled[:train_test_cut], \
    y_shuffled[train_test_cut:]
    
print("Размер массива признаков обучающей выборки", X_train.shape)
print("Размер массива признаков тестовой выборки", X_test.shape)
print("Размер массива ответов для обучающей выборки", y_train.shape)
print("Размер массива ответов для тестовой выборки", y_test.shape)
# Out:
# Размер массива признаков обучающей выборки (70, 2)
# Размер массива признаков тестовой выборки (30, 2)
# Размер массива ответов для обучающей выборки (70,)
# Размер массива ответов для тестовой выборки (30,)

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# %%
def log_loss(w, X, y):
    m = X.shape[0]
    y=y[:, np.newaxis]
    # используем функцию сигмоиды, написанную ранее
    A = sigmoid(np.dot(X, w.T))
    loss = -1.0 / m * np.sum(y * np.log(A) + (1 - y) * np.log(1 - A))
    grad = 1.0 / m * np.dot((A - y).T, X)
    
    return loss, grad

# %%
def optimize(w, X, y, n_iterations, eta):
#     потери будем записывать в список для отображения в виде графика
    losses = []
    
    for i in range(n_iterations):        
        loss, grad = log_loss(w, X, y)
        w = w - eta * grad
        losses.append(loss)
        
    return w, losses

# %%
def predict(w, X):
    y_predicted = np.zeros(X.shape[0])    
    A = sigmoid(np.dot(X, w.T))
#     За порог отнесения к тому или иному классу примем вероятность 0.5
    y_predicted[A[:, 0]>0.5]=1
    y_predicted[A[:, 0]<=0.5]=0
        
    return y_predicted

# %%
w0 = np.zeros((1, X_train.shape[1]))

n_iterations = 1000
eta = 0.05

w, losses = optimize(w0, X_train, y_train, n_iterations, eta)

y_predicted_test = predict(w, X_test)
y_predicted_train = predict(w, X_train)

# В качестве меры точности возьмем долю правильных ответов
train_accuracy = 100.0 - np.mean(np.abs(y_predicted_train - y_train)*100.0)
test_accuracy = 100.0 - np.mean(np.abs(y_predicted_test-y_test)*100.0)

print(f"Итоговый вектор весов w: {w}")
print(f"Точность на обучающей выборке: {train_accuracy:.3f}")
print(f"Точность на тестовой выборке: {test_accuracy:.3f}")
# Out:
# Итоговый вектор весов w: [[3.72659902 0.22383415]]
# Точность на обучающей выборке: 98.571
# Точность на тестовой выборке: 96.667

# %%
plt.title('Log loss')
plt.xlabel('iterations')
plt.ylabel('loss')
plt.plot(range(len(losses)), losses)

# %% [markdown]
# #### В виде класса

# %%
class logistic:
    @staticmethod
    def sigmoid(x):
        return 1 / (1 + np.exp(-x))
    @classmethod
    def log_loss(cls, w, X, y):
        m = X.shape[0]
        y=y[:, np.newaxis]
        # используем функцию сигмоиды, написанную ранее
        A = cls.sigmoid(np.dot(X, w.T))
        loss = -1.0 / m * np.sum(y * np.log(A) + (1 - y) * np.log(1 - A))
        grad = 1.0 / m * np.dot((A - y).T, X)
        return loss, grad
    @classmethod
    def optimize(cls, w, X, y, n_iterations, eta):
        #     потери будем записывать в список для отображения в виде графика
        losses = []
        for i in range(n_iterations):        
            loss, grad = cls.log_loss(w, X, y)
            w = w - eta * grad
            losses.append(loss)
        return w, losses
    def __init__(self, n_iterations=1000, eta=0.05):
        self.n_iterations=1000
        self.eta=0.05
    def fit(self, X, y):
        w0 = np.zeros((1, X.shape[1]))
        self.w, self.losses = optimize(w0, X, y, self.n_iterations, self.eta)
    def predict_proba(self, X):
        y_predicted = np.zeros(X.shape[0])    
        return self.sigmoid(np.dot(X, self.w.T)).flatten()
    def predict(self, X, thr=0.5):
        proba=self.predict_proba(X)
        y_predicted = np.zeros(proba.shape, dtype=bool) 
        y_predicted[proba>thr]=1
        y_predicted[proba<=thr]=0
        return y_predicted

# %%
mod=logistic()
mod.fit(X_train, y_train)
y_predicted_test = mod.predict(X_test)
y_predicted_train = mod.predict(X_train)

# В качестве меры точности возьмем долю правильных ответов
train_accuracy = 100.0 - np.mean(np.abs(y_predicted_train - y_train)*100.0)
test_accuracy = 100.0 - np.mean(np.abs(y_predicted_test-y_test)*100.0)

print(f"Итоговый вектор весов w: {mod.w}")
print(f"Точность на обучающей выборке: {train_accuracy:.3f}")
print(f"Точность на тестовой выборке: {test_accuracy:.3f}")
# Out:
# Итоговый вектор весов w: [[3.72659902 0.22383415]]
# Точность на обучающей выборке: 98.571
# Точность на тестовой выборке: 96.667

# %% [markdown]
# ## Матрица ошибок

# %%
def confusion(predicted, actual):
    TP=np.sum(np.logical_and(predicted==1, actual==1))
    FP=np.sum(np.logical_and(predicted==1, actual==0))
    FN=np.sum(np.logical_and(predicted==0, actual==1))
    TN=np.sum(np.logical_and(predicted==0, actual==0))
    return {'TP': TP, 'FP': FP, 'FN': FN, 'TN': TN}

# %%
print("Для порога по вероятности 0.5 на тестовой выборке имеем:"+
      f" {confusion(mod.predict(X_test), y_test)}")
print("Для порога по вероятности 0.75 на тестовой выборке имеем:"+
      f" {confusion(mod.predict(X_test, 0.6), y_test)}")
# Out:
# Для порога по вероятности 0.5 на тестовой выборке имеем: {'TP': 15, 'FP': 0, 'FN': 1, 'TN': 14}
# Для порога по вероятности 0.75 на тестовой выборке имеем: {'TP': 15, 'FP': 0, 'FN': 1, 'TN': 14}

# %% [markdown]
# ## Методы оценки дискриминационной способности модели

# %%
from numpy import trapz  # используем эту функцию для расчета площади под кривой

TPR = [0, 0.33, 0.33, 0.66, 1, 1, 1]
FPR = [0, 0, 0.33, 0.33, 0.33, 0.66, 1]

AUC_ROC = trapz(TPR, x = FPR, dx=0.1)

plt.title('ROC curve')
plt.ylim(0, 1.05)
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.grid()
plt.legend(' ', title=f'AUC-ROC={AUC_ROC:.3f}', loc='lower right')
plt.plot(FPR, TPR)

# %%
precision = [0, 1, 0.5, 0.66, 0.75, 0.6, 0.5]
recall = [0, 0.33, 0.33, 0.66, 1, 1, 1]

AUC_PR = trapz(precision, x = recall, dx=0.1)

plt.title('PR curve')
plt.ylim(0, 1.05)
plt.xlabel('recall')
plt.ylabel('presision')
plt.grid()
plt.legend(' ', title=f'AUC-PR={AUC_PR:.3f}', loc='lower right')
plt.plot(recall, precision)

# %% [markdown]
# <b>Домашнее задание:</b><br>
# Определите AUC_ROC и AUC_ROC для построенной модели на тестовой выборке.<br>
# Используйте реализацию модели в виде класса и функцию confusion,<br>
# чтобы рассчитать TPR, FPR, precision, recal для различных порогов вероятности.

# %% [markdown]
# <center>$\large precision = \LARGE \frac{TP}{TP \: + \: FP} \:\:\:\:\: \large recall = \LARGE \frac{TP}{TP \: + \: FN}$<center>

# %% [markdown]
# <center>$\large TPR = \LARGE \frac{TP}{TP \: + \: FN} \:\:\:\:\: \large FPR = \LARGE \frac{FP}{FP \: + \: TN}$<center>

# %%
def get_dict_precision_recall_TPR_FPR(conf_m):
    """
    Функция принимает на вход матрицу ошибок.
    Функция возвращает значения метрик в виде словаря.
    """
    TPR = conf_m['TP']/(conf_m['TP'] + conf_m['FN'])
    FPR = conf_m['FP']/(conf_m['FP'] + conf_m['TN'])
    precision = conf_m['TP']/(conf_m['TP']+conf_m['FP'])
    recall = conf_m['TP']/(conf_m['TP']+conf_m['FN'])
    return {'precision': precision, 'recall': recall, 'TPR': TPR, 'FPR': FPR}

# %%
threshold = np.unique(mod.predict_proba(X_test))
threshold
# Out:
# array([0.00316902, 0.00339099, 0.00538997, 0.00706722, 0.00832595,
#        0.03030468, 0.03242187, 0.04710795, 0.05989168, 0.06105908,
#        0.06989233, 0.1958731 , 0.25512996, 0.2556132 , 0.32346379,
#        0.6353378 , 0.83095541, 0.84473367, 0.89629895, 0.89667926,
#        0.92817718, 0.9422805 , 0.95105005, 0.95865913, 0.96057957,
#        0.96876842, 0.97345903, 0.97559418, 0.977738  , 0.99071079])

# %%
TPR_list = []
FPR_list = []
precision_list = []
recall_list = []
for _thr in threshold:
    if _thr >0.9907107:
        _thr=0.9907107
    res = get_dict_precision_recall_TPR_FPR(confusion(mod.predict(X_test, thr=_thr), y_test))
    print(f"Для порога по вероятности {_thr} на тестовой выборке имеем:\n"
      f" {res}\n")
    precision_list.append(res['precision'])
    recall_list.append(res['recall'])
    TPR_list.append(res['TPR'])
    FPR_list.append(res['FPR'])
# Out:
# Для порога по вероятности 0.003169023069113651 на тестовой выборке имеем:
#  {'precision': 0.5517241379310345, 'recall': 1.0, 'TPR': 1.0, 'FPR': 0.9285714285714286}
#
# Для порога по вероятности 0.003390990505893634 на тестовой выборке имеем:
#  {'precision': 0.5714285714285714, 'recall': 1.0, 'TPR': 1.0, 'FPR': 0.8571428571428571}
#
# Для порога по вероятности 0.005389968747199874 на тестовой выборке имеем:
#  {'precision': 0.5925925925925926, 'recall': 1.0, 'TPR': 1.0, 'FPR': 0.7857142857142857}
#
# Для порога по вероятности 0.00706721735198714 на тестовой выборке имеем:
#  {'precision': 0.6153846153846154, 'recall': 1.0, 'TPR': 1.0, 'FPR': 0.7142857142857143}
#
# Для порога по вероятности 0.008325953254938644 на тестовой выборке имеем:
#  {'precision': 0.64, 'recall': 1.0, 'TPR': 1.0, 'FPR': 0.6428571428571429}
#
# Для порога по вероятности 0.0303046849304672 на тестовой выборке имеем:
#  {'precision': 0.6666666666666666, 'recall': 1.0, 'TPR': 1.0, 'FPR': 0.5714285714285714}
#
# Для порога по вероятности 0.032421873104532366 на тестовой выборке имеем:
#  {'precision': 0.6956521739130435, 'recall': 1.0, 'TPR': 1.0, 'FPR': 0.5}
#
# Для порога по вероятности 0.04710794934641212 на тестовой выборке имеем:
#  {'precision': 0.7272727272727273, 'recall': 1.0, 'TPR': 1.0, 'FPR': 0.42857142857142855}
#
# Для порога по вероятности 0.05989168076709762 на тестовой выборке имеем:
#  {'precision': 0.7619047619047619, 'recall': 1.0, 'TPR': 1.0, 'FPR': 0.35714285714285715}
#
# Для порога по вероятности 0.06105908130089521 на тестовой выборке имеем:
#  {'precision': 0.8, 'recall': 1.0, 'TPR': 1.0, 'FPR': 0.2857142857142857}
#
# Для порога по вероятности 0.0698923274568787 на тестовой выборке имеем:
#  {'precision': 0.8421052631578947, 'recall': 1.0, 'TPR': 1.0, 'FPR': 0.21428571428571427}
#
# Для порога по вероятности 0.19587309964897417 на тестовой выборке имеем:
#  {'precision': 0.8888888888888888, 'recall': 1.0, 'TPR': 1.0, 'FPR': 0.14285714285714285}
#
# Для порога по вероятности 0.2551299561570264 на тестовой выборке имеем:
#  {'precision': 0.9411764705882353, 'recall': 1.0, 'TPR': 1.0, 'FPR': 0.07142857142857142}
#
# Для порога по вероятности 0.2556131981694702 на тестовой выборке имеем:
#  {'precision': 0.9375, 'recall': 0.9375, 'TPR': 0.9375, 'FPR': 0.07142857142857142}
#
# Для порога по вероятности 0.3234637861669007 на тестовой выборке имеем:
#  {'precision': 1.0, 'recall': 0.9375, 'TPR': 0.9375, 'FPR': 0.0}
#
# Для порога по вероятности 0.6353378041707626 на тестовой выборке имеем:
#  {'precision': 1.0, 'recall': 0.875, 'TPR': 0.875, 'FPR': 0.0}
#
# Для порога по вероятности 0.8309554148280416 на тестовой выборке имеем:
#  {'precision': 1.0, 'recall': 0.8125, 'TPR': 0.8125, 'FPR': 0.0}
#
# Для порога по вероятности 0.8447336730525334 на тестовой выборке имеем:
#  {'precision': 1.0, 'recall': 0.75, 'TPR': 0.75, 'FPR': 0.0}
#
# Для порога по вероятности 0.896298951223434 на тестовой выборке имеем:
#  {'precision': 1.0, 'recall': 0.6875, 'TPR': 0.6875, 'FPR': 0.0}
#
# Для порога по вероятности 0.8966792647841713 на тестовой выборке имеем:
#  {'precision': 1.0, 'recall': 0.625, 'TPR': 0.625, 'FPR': 0.0}
#
# Для порога по вероятности 0.9281771812064595 на тестовой выборке имеем:
#  {'precision': 1.0, 'recall': 0.5625, 'TPR': 0.5625, 'FPR': 0.0}
#
# Для порога по вероятности 0.9422804950205523 на тестовой выборке имеем:
#  {'precision': 1.0, 'recall': 0.5, 'TPR': 0.5, 'FPR': 0.0}
#
# Для порога по вероятности 0.951050046520953 на тестовой выборке имеем:
#  {'precision': 1.0, 'recall': 0.4375, 'TPR': 0.4375, 'FPR': 0.0}
#
# Для порога по вероятности 0.9586591339575495 на тестовой выборке имеем:
#  {'precision': 1.0, 'recall': 0.375, 'TPR': 0.375, 'FPR': 0.0}
#
# Для порога по вероятности 0.9605795697396091 на тестовой выборке имеем:
#  {'precision': 1.0, 'recall': 0.3125, 'TPR': 0.3125, 'FPR': 0.0}
#
# Для порога по вероятности 0.9687684194620356 на тестовой выборке имеем:
#  {'precision': 1.0, 'recall': 0.25, 'TPR': 0.25, 'FPR': 0.0}
#
# Для порога по вероятности 0.9734590336629443 на тестовой выборке имеем:
#  {'precision': 1.0, 'recall': 0.1875, 'TPR': 0.1875, 'FPR': 0.0}
#
# Для порога по вероятности 0.9755941841903596 на тестовой выборке имеем:
#  {'precision': 1.0, 'recall': 0.125, 'TPR': 0.125, 'FPR': 0.0}
#
# Для порога по вероятности 0.9777380002723363 на тестовой выборке имеем:
#  {'precision': 1.0, 'recall': 0.0625, 'TPR': 0.0625, 'FPR': 0.0}
#
# Для порога по вероятности 0.9907107 на тестовой выборке имеем:
#  {'precision': 1.0, 'recall': 0.0625, 'TPR': 0.0625, 'FPR': 0.0}

# %%
AUC_ROC = trapz(TPR_list[::-1], x = FPR_list[::-1], dx=0.1)

plt.title('ROC curve')
plt.ylim(0, 1.05)
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.grid()
plt.legend(' ', title=f'AUC-ROC={AUC_ROC:.3f}', loc='lower right')
plt.plot(FPR_list, TPR_list)

# %%
AUC_PR = trapz(precision_list[::-1], x = recall_list[::-1], dx=0.1)

plt.title('PR curve')
plt.ylim(0, 1.05)
plt.xlabel('recall')
plt.ylabel('presision')
plt.grid()
plt.legend(' ', title=f'AUC-PR={AUC_PR:.3f}', loc='lower right')
plt.plot(recall_list, precision_list)
